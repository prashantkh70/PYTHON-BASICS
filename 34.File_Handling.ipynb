# %% [markdown]
# # File Handling

# %%
Text  >>> 
JSON
ML Model (pickle)
objects (one hot encoding)

Data needs to be stored
>> writing file >> storage
>> reading file >> retrival

# %% [markdown]
# # File Operations

# %%
1. write  
2. read  
3. append

# %% [markdown]
# # open function

# %%
open(file_name or file_path , mode = 'r')
we need to close the function
close()

# %% [markdown]
# # Modes:

# %%
Modes:
    1. read mode   >> 'r'
    2. write mode  >> 'w'
    3. write mode  >> 'x'
    4. append mode >> 'a'
    5. read bytes  >> 'rb'
    6. write bytes  >> 'wb'

# %% [markdown]
# # 1. Write Mode

# %%
write mode >> 'w'
It will create a new file, if not exists.
It will overwrite a text , if file is already exists.

# %%
f = open('sample.txt', 'w')
f.write('We are learning File Handling')
f.close()

# %%
f = open('sample.txt', 'w')
f.write('We are learning Data Science')
f.close()

# %%
text = '''Data science is an interdisciplinary field that 
uses scientific methods, processes, algorithms and systems 
to extract knowledge and insights from noisy, structured and 
unstructured data, and apply knowledge 
from data across a broad range of application domains'''

f = open('data_science.txt', 'w')
f.write(text)
f.close()

# %%
text = '''Data science is an interdisciplinary field that 
uses scientific methods, processes, algorithms and systems



to extract knowledge and insights from noisy, structured and 
unstructured data, and apply knowledge 
from data across a broad range of application domains'''

f = open('data_science.txt', 'w')
f.write(text)
f.close()

# %% [markdown]
# # 2. append()

# %%
append mode >> 'a'
it create a new file if not exists.
It will add text in existing text file.

# %%
f = open('new_file.txt', 'a')
f.write('We are learning file handling\n')
f.close()

# %%
f = open('new_file.txt', 'a')
f.write('We are learning append mode')
f.close()

# %%
f = open('new_file.txt', 'a')
f.write('\nWe are learning last added item')
f.close()

# %%
f = open('new_file.txt', 'a')
f.write('\n1233456789')
f.close()

# %% [markdown]
# # 3. read()

# %%
f = open(file_name , 'r')

# %%
1. read
2. readlines
3. readline

# %%
text = '''Data science is an interdisciplinary field that 
uses scientific methods, processes, algorithms and systems 
to extract knowledge and insights from noisy, structured and 
unstructured data, and apply knowledge 
from data across a broad range of application domains'''

f = open('ds_read.txt', 'w')
f.write(text)
f.close()

# %%
f = open('ds_read.txt', 'r')
data =f.read()
f.close()

print(data)
# Out:
# Data science is an interdisciplinary field that
# uses scientific methods, processes, algorithms and systems
# to extract knowledge and insights from noisy, structured and
# unstructured data, and apply knowledge
# from data across a broad range of application domains

# %%
f = open('new_file.txt', 'r')
data =f.read()
f.close()

print(data)
# Out:
# We are learning file handlingWe are learning append modeWe are learning file handling
# We are learning append mode
# We are learning last added item
# 1233456789

# %%
f = open('data_science.txt', 'r')
data =f.read()
f.close()

print(data)
# Out:
# Data science is an interdisciplinary field that
# uses scientific methods, processes, algorithms and systems
#
#
#
# to extract knowledge and insights from noisy, structured and
# unstructured data, and apply knowledge
# from data across a broad range of application domains

# %%
f = open(r'C:\Users\Vaibhav\Downloads\Medicalpremium.csv', 'r')
data =f.read()
f.close()

print(data)
# Out:
# Age,Diabetes,BloodPressureProblems,AnyTransplants,AnyChronicDiseases,Height,Weight,KnownAllergies,HistoryOfCancerInFamily,NumberOfMajorSurgeries,PremiumPrice
# 45,0,0,0,0,155,57,0,0,0,25000
# 48,0,1,0,0,172,59,0,0,1,25000
# 64,0,1,0,0,174,64,0,0,1,25000
# 22,1,0,0,0,158,64,1,0,1,15000
# 39,0,0,0,0,161,52,0,0,0,23000
# 19,0,0,0,0,158,73,0,0,0,18000
# 18,1,1,0,0,176,63,0,0,1,15000
# 59,0,1,0,0,162,51,1,0,0,16000
# 60,0,1,0,0,171,74,0,1,2,28000
# 27,0,0,0,0,162,74,0,0,0,16000
# 50,0,0,0,0,158,76,0,1,2,28000
# 20,1,0,0,0,181,77,1,1,1,16000
# 39,0,0,0,1,185,73,1,1,1,31000
# 64,1,1,0,0,179,73,1,0,2,28000
# 58,0,1,1,0,163,51,1,0,2,28000
# 32,0,0,0,0,184,68,0,0,1,23000
# 19,0,0,0,0,176,53,0,0,0,15000
# 19,1,0,0,0,183,70,1,1,1,15000
# 22,0,0,0,0,174,74,1,0,1,15000
# 61,1,0,0,0,178,71,0,0,3,28000
# 58,0,0,1,0,179,62,0,0,0,38000
# 29,1,0,0,0,174,56,0,0,0,15000
# 56,1,1,0,0,177,58,0,0,1,25000
# 24,0,1,0,0,180,62,0,0,0,15000
# 65,1,0,0,0,184,78,0,0,3,28000
# 24,1,1,1,0,166,74,1,0,0,15000
# 48,0,0,0,1,175,70,0,0,0,30000
# 42,1,0,0,0,186,58,0,0,0,23000
# 44,1,0,0,0,168,76,1,0,0,23000
# 26,1,1,0,0,167,70,0,1,1,15000
# 49,0,1,0,1,185,73,1,1,1,30000
# 35,1,0,0,0,173,60,0,0,0,23000
# 58,1,1,0,0,165,63,0,0,0,25000
# 47,0,1,0,0,170,77,0,0,1,23000
# 57,0,0,0,1,165,56,0,0,0,25000
# 46,0,1,0,0,174,54,0,0,0,25000
# 41,1,1,0,0,167,70,0,0,1,23000
# 18,0,0,0,0,181,65,1,1,1,15000
# 49,1,1,0,0,166,75,0,1,2,28000
# 32,0,0,0,0,185,65,0,1,1,21000
# 45,1,0,0,1,181,58,0,0,1,25000
# 27,0,0,0,0,165,63,0,0,0,15000
# 56,1,0,0,0,168,69,0,0,0,25000
# 42,0,0,0,0,183,62,0,0,0,23000
# 64,0,1,0,1,180,60,1,1,1,25000
# 58,1,0,0,0,176,51,0,0,0,25000
# 56,0,0,0,1,184,68,1,0,1,25000
# 58,0,1,0,0,180,63,0,0,0,25000
# 45,0,1,0,0,167,78,0,0,0,23000
# 45,0,0,0,1,175,54,0,0,0,25000
# 30,0,0,0,0,166,54,0,0,1,21000
# 33,0,1,0,0,170,54,0,0,1,21000
# 59,1,1,0,0,175,68,0,0,1,25000
# 27,1,0,0,0,184,64,0,0,0,15000
# 30,0,1,0,0,174,52,0,0,1,21000
# 64,1,1,0,0,178,62,0,1,2,28000
# 34,0,1,0,0,172,62,0,0,1,23000
# 51,0,1,0,0,174,65,1,0,1,25000
# 35,0,0,0,0,184,63,0,0,0,23000
# 62,0,1,0,0,167,67,0,0,2,28000
# 46,1,1,0,0,168,61,0,0,0,25000
# 45,0,0,0,0,172,81,0,0,1,23000
# 26,0,0,0,1,184,73,0,0,1,19000
# 50,1,0,0,0,168,75,0,0,2,28000
# 65,1,0,1,0,171,94,0,0,3,28000
# 65,1,0,0,0,165,99,0,0,3,28000
# 50,0,0,0,0,147,64,0,0,1,25000
# 40,0,1,0,0,161,67,1,1,1,31000
# 65,1,1,0,0,169,80,0,0,2,28000
# 18,0,1,0,0,163,82,0,0,0,15000
# 62,1,1,0,0,150,64,0,0,2,28000
# 36,1,1,0,0,157,95,0,0,0,23000
# 32,0,1,0,0,177,98,0,1,1,25000
# 52,0,1,0,1,148,70,0,1,2,28000
# 27,0,0,0,0,175,86,0,0,1,15000
# 65,1,1,0,0,158,83,0,0,0,29000
# 31,0,0,0,0,150,91,1,0,1,23000
# 52,1,1,0,0,176,82,0,1,1,31000
# 26,0,0,0,1,147,67,0,0,0,21000
# 40,0,0,0,0,170,83,0,0,0,23000
# 25,1,0,0,0,151,92,0,1,1,15000
# 21,0,1,0,0,156,99,0,0,0,15000
# 21,0,0,0,0,176,88,0,0,0,15000
# 29,1,0,0,0,145,62,0,0,0,15000
# 50,0,1,0,0,164,74,0,0,2,28000
# 44,0,0,0,0,174,57,0,0,0,23000
# 56,1,1,0,1,159,59,0,0,2,28000
# 48,0,0,0,0,150,89,0,0,0,23000
# 56,1,0,1,0,149,65,0,0,2,28000
# 50,0,0,0,1,174,72,0,0,0,30000
# 60,1,1,0,1,145,63,0,0,2,28000
# 18,0,0,0,0,154,60,0,0,0,15000
# 41,0,0,0,0,166,58,0,0,0,23000
# 35,0,1,0,0,160,75,0,0,0,23000
# 24,1,0,0,0,174,100,0,0,0,15000
# 22,0,0,0,0,169,86,1,1,1,15000
# 20,0,0,0,0,169,66,0,0,0,15000
# 48,1,0,0,0,153,74,1,1,1,31000
# 18,0,0,0,0,170,72,0,0,1,15000
# 61,0,1,0,1,163,66,0,0,1,25000
# 37,1,1,0,0,150,69,0,0,0,23000
# 54,0,1,0,1,156,67,0,0,2,28000
# 29,1,0,0,0,156,74,0,0,0,15000
# 21,0,0,0,0,170,75,0,0,0,15000
# 55,0,0,0,0,153,73,0,0,0,29000
# 65,0,1,0,1,166,73,0,0,1,35000
# 28,1,0,0,0,160,69,0,0,0,15000
# 61,1,0,0,0,161,66,0,0,3,28000
# 44,0,0,0,0,162,75,0,0,0,23000
# 53,0,1,0,1,172,75,0,0,1,30000
# 25,0,0,1,0,175,74,0,0,0,15000
# 33,1,1,0,0,169,73,1,0,1,23000
# 66,0,1,1,0,154,66,1,0,1,35000
# 28,1,1,0,0,147,69,0,0,1,15000
# 62,1,1,0,0,166,67,0,0,1,25000
# 25,0,0,0,0,164,66,0,0,0,15000
# 18,0,1,0,0,164,68,0,0,1,15000
# 39,1,0,0,0,168,68,1,1,1,31000
# 28,1,0,0,0,175,68,0,0,1,15000
# 42,0,0,0,0,155,69,0,0,1,23000
# 35,1,0,0,0,173,69,0,0,0,23000
# 51,1,1,0,0,152,72,0,0,1,29000
# 48,1,0,0,0,150,67,0,1,1,25000
# 51,1,1,0,0,164,66,0,0,1,25000
# 23,0,0,0,0,148,69,0,0,0,15000
# 53,0,1,0,1,158,68,0,0,2,28000
# 25,1,1,0,1,151,70,0,0,0,19000
# 53,0,0,0,0,173,66,0,1,1,25000
# 43,0,0,0,0,166,73,0,0,1,23000
# 55,0,0,0,0,157,73,0,0,0,29000
# 45,0,1,0,0,165,73,1,0,0,23000
# 29,0,0,0,0,154,72,0,0,0,15000
# 60,1,1,0,0,155,69,0,0,0,25000
# 30,1,1,0,0,152,71,0,0,1,23000
# 52,1,1,0,0,161,67,0,0,2,28000
# 25,0,0,1,0,161,69,1,0,1,15000
# 44,1,0,1,0,174,66,0,0,1,38000
# 62,1,1,0,0,157,66,0,0,3,28000
# 63,1,1,0,0,158,73,0,0,3,28000
# 21,1,0,0,0,147,66,0,0,0,15000
# 46,1,1,0,0,146,67,0,0,0,25000
# 27,1,1,0,0,155,75,0,0,1,15000
# 18,0,0,0,0,162,70,0,0,0,15000
# 66,0,1,0,0,153,75,0,0,2,28000
# 23,0,0,0,0,175,73,0,0,0,15000
# 59,1,1,0,0,154,66,0,1,1,25000
# 32,1,1,0,0,166,70,1,0,0,23000
# 49,1,0,0,0,147,67,0,0,1,25000
# 27,1,0,0,0,162,69,0,0,0,15000
# 35,1,1,0,0,165,67,0,0,1,23000
# 66,0,1,0,1,176,71,1,0,1,35000
# 42,1,1,0,0,152,67,1,0,1,23000
# 18,0,0,0,0,160,73,0,0,0,15000
# 45,0,1,0,0,168,66,0,0,0,25000
# 46,1,1,0,0,168,75,0,0,1,23000
# 26,0,0,0,0,178,66,0,0,0,15000
# 31,0,1,0,0,152,75,1,0,1,23000
# 28,0,0,0,0,167,66,0,0,0,15000
# 47,1,0,0,0,170,66,0,0,0,25000
# 44,0,1,0,0,161,75,0,0,0,23000
# 21,0,1,0,0,155,74,0,0,0,39000
# 45,0,1,0,1,157,67,0,0,1,25000
# 40,0,1,1,0,168,70,0,0,0,17000
# 24,0,0,0,0,161,71,0,0,0,15000
# 40,0,1,1,0,171,74,0,0,0,38000
# 18,0,0,0,0,169,67,0,0,0,15000
# 64,1,1,0,0,153,70,0,0,3,28000
# 56,0,1,0,0,155,71,0,0,1,29000
# 47,1,1,0,0,158,73,1,0,1,39000
# 21,0,0,0,0,158,75,1,0,1,15000

# %% [markdown]
# ### 2. readlines()

# %%
Return the list of all lines

# %%
data in file:
    
Data science is an interdisciplinary field that 
uses scientific methods, processes, algorithms and systems 
to extract knowledge and insights from noisy, structured and 
unstructured data, and apply knowledge 
from data across a broad range of application domains

# %%
f = open('ds_read.txt', 'r')
text_list =f.readlines()
f.close()

print(text_list)
# Out:
# ['Data science is an interdisciplinary field that \n', 'uses scientific methods, processes, algorithms and systems \n', 'to extract knowledge and insights from noisy, structured and \n', 'unstructured data, and apply knowledge \n', 'from data across a broad range of application domains']

# %%
f = open('new_file.txt', 'r')
text_list =f.readlines()
f.close()

print(text_list)
# Out:
# ['We are learning file handlingWe are learning append modeWe are learning file handling\n', 'We are learning append mode\n', 'We are learning last added item\n', '1233456789']

# %%
f = open('data_science.txt', 'r')
text_list =f.readlines()
f.close()

print(text_list)
# Out:
# ['Data science is an interdisciplinary field that \n', 'uses scientific methods, processes, algorithms and systems\n', '\n', '\n', '\n', 'to extract knowledge and insights from noisy, structured and \n', 'unstructured data, and apply knowledge \n', 'from data across a broad range of application domains']

# %% [markdown]
# ### 3. readline()

# %%
f = open('data_science.txt', 'r')
text_list =f.readline()
print(text_list)

text_list1 =f.readline()
print(text_list1)
f.close()
# Out:
# Data science is an interdisciplinary field that
#
# uses scientific methods, processes, algorithms and systems

# %%
f = open('new_file.txt', 'r')
text_list =f.readline()
print(text_list)
text_list =f.readline()
print(text_list)
text_list =f.readline()
print(text_list)
text_list =f.readline()
print(text_list)
text_list =f.readline()
print(text_list)
f.close()
# Out:
# We are learning file handlingWe are learning append modeWe are learning file handling
#
# We are learning append mode
#
# We are learning last added item
#
# 1233456789

# %% [markdown]
# # 4. write()

# %%
write mode >> 'x'
it creates file if not exists
it avoids overwriting

# %%
f = open('testing.txt', 'x')
f.write('We are learning data science')
f.close()

# %%
f = open('testing.txt', 'x')
f.write('We are learning data science')
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-35-b529aa0cb540> in <module>
# ----> 1 f = open('testing.txt', 'x')
#       2 f.write('We are learning data science')
#       3 f.close()
#
# FileExistsError: [Errno 17] File exists: 'testing.txt'

# %% [markdown]
# # with statement

# %%
no need to use close function
with statement automatically close file operation

# %%
f = open('close.txt', 'w')
f.write('We are learning Data Science')
f.close()

# %%
with open('data1.txt', 'w') as f:
    f.write('We are learning with statement')

# %%
with open('data1.txt', 'a') as f:
    f.write('\nWe are learning with statement')

# %%
with open('data1.txt','r')as f:
    text=f.read()

# %%
print(text)
# Out:
# We are learning with statement
# We are learning with statement

# %% [markdown]
# # JSON Files
#
# import json

# %%
dict1 ={'key':'value'}
data = """{'Name':'Virat', 'Age':29,'Designation': 'Data Scientist'}"""

with open('emp_data.json', 'w')as f:
    f.write(data)

# %%
with open('emp_data.json', 'r')as f:
    json=f.read()

print(json)
# Out:
# {'Name':'Virat', 'Age':29,'Designation': 'Data Scientist'}

# %%
import json
employee_details = { "TCS1005": {'Name':'Virat',
                                 'Age':29,
                                 'Designation': 'Data Scientist'},
                    "TCS1006": {'Name':'Rahul',
                                 'Age':30,
                                 'Designation': 'Data Analyst'},
                    "TCS1007": {'Name':'Alok',
                                 'Age':28,
                                 'Designation': 'Application Developer'}}

with open('employee_details.json', 'w') as f:
    json.dump(employee_details, f)

# %% [markdown]
# # Read Json File

# %%
with open('employee_details.json', 'r') as f:
    data=json.load(f)
    
print(data)
# Out:
# {'TCS1005': {'Name': 'Virat', 'Age': 29, 'Designation': 'Data Scientist'}, 'TCS1006': {'Name': 'Rahul', 'Age': 30, 'Designation': 'Data Analyst'}, 'TCS1007': {'Name': 'Alok', 'Age': 28, 'Designation': 'Application Developer'}}

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# ### 1. save model files

# %%
# from sklearn.linear_model import LinearRegression,LogisticRegression

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\vaibhav\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\vaibhav\anaconda3\lib\site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\vaibhav\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vaibhav\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\vaibhav\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\vaibhav\appdata\roaming\python\python38\site-packages (from scikit-learn->sklearn) (1.22.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.tree import DecisionTreeRegressor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-371378d9b90b> in <module>
# ----> 1 from sklearn.tree import DecisionTreeRegressor
#
# ~\anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in <module>
#      21
#      22 from .murmurhash import murmurhash3_32
# ---> 23 from .class_weight import compute_class_weight, compute_sample_weight
#      24 from . import _joblib
#      25 from ..exceptions import DataConversionWarning
#
# ~\anaconda3\lib\site-packages\sklearn\utils\class_weight.py in <module>
#       5 import numpy as np
#       6
# ----> 7 from .validation import _deprecate_positional_args
#       8
#       9
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in <module>
#      24 from contextlib import suppress
#      25
# ---> 26 from .fixes import _object_dtype_isnan, parse_version
#      27 from .. import get_config as _get_config
#      28 from ..exceptions import PositiveSpectrumWarning
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in <module>
#      18 import scipy.sparse as sp
#      19 import scipy
# ---> 20 import scipy.stats
#      21 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      22 from numpy.ma import MaskedArray as _MaskedArray  # TODO: remove in 1.0
#
# ~\anaconda3\lib\site-packages\scipy\stats\__init__.py in <module>
#     389
#     390 """
# --> 391 from .stats import *
#     392 from .distributions import *
#     393 from .morestats import *
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in <module>
#     178 import scipy.special as special
#     179 from scipy import linalg
# --> 180 from . import distributions
#     181 from . import mstats_basic
#     182 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#
# ~\anaconda3\lib\site-packages\scipy\stats\distributions.py in <module>
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (entropy, rv_discrete, rv_continuous,
#       9                                     rv_frozen)
#      10
#
# ~\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in <module>
#      21
#      22 # for root finding for continuous distribution ppf, and max likelihood estimation
# ---> 23 from scipy import optimize
#      24
#      25 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\__init__.py in <module>
#     398 """
#     399
# --> 400 from .optimize import *
#     401 from ._minimize import *
#     402 from ._root import *
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in <module>
#      34                          line_search_wolfe2 as line_search,
#      35                          LineSearchWarning)
# ---> 36 from ._numdiff import approx_derivative
#      37 from scipy._lib._util import getfullargspec_no_self as _getfullargspec
#      38 from scipy._lib._util import MapWrapper
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py in <module>
#       4 from numpy.linalg import norm
#       5
# ----> 6 from scipy.sparse.linalg import LinearOperator
#       7 from ..sparse import issparse, csc_matrix, csr_matrix, coo_matrix, find
#       8 from ._group_columns import group_dense, group_sparse
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\__init__.py in <module>
#     112 from .dsolve import *
#     113 from .interface import *
# --> 114 from .eigen import *
#     115 from .matfuncs import *
#     116 from ._onenormest import *
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\__init__.py in <module>
#       7
#       8 """
# ----> 9 from .arpack import *
#      10 from .lobpcg import *
#      11
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\__init__.py in <module>
#      18
#      19 """
# ---> 20 from .arpack import *
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in <module>
#      40 __all__ = ['eigs', 'eigsh', 'svds', 'ArpackError', 'ArpackNoConvergence']
#      41
# ---> 42 from . import _arpack
#      43 arpack_int = _arpack.timing.nbx.dtype
#      44
#
# ImportError: DLL load failed while importing _arpack: The specified procedure could not be found.

# %%
with open('linear_model.pkl','wb') as f:
    pickle.dump(model,f)
